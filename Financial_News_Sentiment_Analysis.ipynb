# %% [markdown]
# Data Acquisition

# %%
import requests
from bs4 import BeautifulSoup

def scrape_headlines(url):
    """Scrapes news headlines from a given website URL and returns them as a list.

    Args:
        url (str): The URL of the website to scrape.

    Returns:
        list: A list of headlines extracted from the website, or an empty list if an error occurs.
    """

    try:
        response = requests.get(url)
        response.raise_for_status()

        soup = BeautifulSoup(response.content, 'html.parser')

        headlines = []
        for heading_tag in ['h1', 'h2', 'h3', 'h4', 'h5', 'h6']:
            headlines.extend(soup.find_all(heading_tag))

        headline_text = [headline.text.strip() for headline in headlines]
        return headline_text

    except requests.exceptions.RequestException as e:
        print(f"Error fetching the URL: {e}")
        return []

if __name__ == "__main__":
    target_url = input("Enter the website URL to scrape: ")
    headlines_list = scrape_headlines(target_url)
    headlines_list = headlines_list[20::]
    print(headlines_list)

# using https://finance.yahoo.com/news/
# Out:
# Enter the website URL to scrape: https://finance.yahoo.com/news/
# ['Russia raises forecast for 2024 oil, gas export revenues by $17.4 billion', 'US Gulf Coast-bound fuel oil cargoes hit 5-yr low as refinery demand weakens', 'How steelworkers are gambling on politics to block — or improve — the Nippon-US Steel deal', 'S&P 500 Heads Toward Worst Week Since March 2023: Markets Wrap', 'Nvidia stock tanks 5% amid rough week for chip stocks', 'Florida Boomtown Borrows $65 Million to Help Fix Bursting Jail', 'Why Gitlab Stock Rallied This Week', 'Analysts adjust Bookings.com stock price target on travel market', "Stocks Tumble On Jobs Data, Nasdaq 100 Eyes Worst Week In 2 Years As Semiconductors Slump: What's Driving Markets Friday?", '1 Wall Street Team Thinks Super Micro Computer Stock Is Going to $438. Is It Time to Sell?', 'Why Nvidia Stock Is Plummeting Again Today', 'Buy British stocks, says Goldman Sachs', 'Spectrum Brands (NYSE:SPB) Q2 Earnings: Leading The Household Products Pack', 'Q2 Earnings Highlights: Snap-on (NYSE:SNA) Vs The Rest Of The Professional Tools and Equipment Stocks', 'Firing on All Cylinders: Sprouts (NASDAQ:SFM) Q2 Earnings Lead the Way', "Q2 Earnings Highs And Lows: O'Reilly (NASDAQ:ORLY) Vs The Rest Of The Auto Parts Retailer Stocks", 'Q2 Automotive and Marine Retail Earnings: MarineMax (NYSE:HZO) Impresses', 'Q2 Ground Transportation Earnings Review: First Prize Goes to Heartland Express (NASDAQ:HTLD)', 'Utilities are almost as big an AI play as tech: Strategist', 'Vivek Ramaswamy talks Fed policy, crypto, US economy agendas', 'How Dell is riding the AI wave: Insights from CEO Michael Dell', 'America has forgotten how to build homes: Redfin CEO', "Expect China to 'fight hard' against chip export controls", 'How steelworkers are gambling on politics to block — or improve — the Nippon-US Steel deal', 'Nvidia stock tanks 5% amid rough week for chip stocks', 'Stock market today: Stocks erase gains, head for big weekly losses after jobs report', "'The time has come': Why the August jobs report keeps the Fed on track for a 25 basis point rate cut", 'One of the biggest AI stocks of the year hit with downgrade from JPMorgan', 'August jobs report: Unemployment rate falls to 4.2%, labor market adds 142,000 jobs', '\u200b\u200bCrypto won’t dethrone the dollar: CEO of America’s oldest bank', "The US economy may be on 'thinner' ice than investors think", 'Fed Likely Ready to Start Cutting Rates, Governor Waller, NY Fed President Williams Say', "Apple's iPhone 16 Launch to Trigger 'Biggest Upgrade Cycle' Yet, Wedbush Reiterates", 'ABM Industries Lifts Full-Year Earnings Outlook as Fiscal Third-Quarter Results Beat Estimates', 'August Nonfarm Payrolls Miss Estimates, Unemployment Rate Edges Down', 'BRP Slashes Full-Year Outlook as Lower Demand Impacts Fiscal Second-Quarter Results', 'DocuSign Lifts Full-Year Revenue Guidance Following Fiscal Second-Quarter Beat', 'Stock Futures Fall Ahead of August Jobs Report; Asia, Europe Down', 'Nvidia’s AI chips are cheaper to rent in China than US', 'New Zealand Housing Construction Slump Highlights Recession Risk', 'Mortgage rates falling to 5% would get this party started', 'Zoning reforms won’t save us, housing experts warn in Fannie survey', 'Mortgage rates remain steady as Fed rate cut looms', 'Average long-term US mortgage rates holds at 6.35% this week ahead of expected Fed rate cut', 'Mortgage Rates in the US Hold at the Lowest Level Since May 2023', 'These counties have the greatest risk of a housing downturn', 'California settles lawsuit with Sacramento suburb over affordable housing project', '7 ways to build credit — without a credit card', 'How does inflation affect mortgage rates?', 'Mortgage and refinance rates today, September 6, 2024: Rates drop 77 basis points in a year', 'Russia raises forecast for 2024 oil, gas export revenues by $17.4 billion', 'US Gulf Coast-bound fuel oil cargoes hit 5-yr low as refinery demand weakens', 'S&P 500 Heads Toward Worst Week Since March 2023: Markets Wrap', 'Nvidia’s $400 Billion Tumble This W ...

# %% [markdown]
# Load Tokenizer and Model

# %%
from transformers import BertTokenizer, BertForSequenceClassification

tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')

model = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# Tokenize

# %%
import torch
def get_sentiment(headline):
    inputs = tokenizer(headline, return_tensors="pt", truncation=True, padding=True, max_length=512)
    outputs = model(**inputs)
    probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
    sentiment = torch.argmax(probs, dim=1).item()  # 0: Negative, 1: Neutral, 2: Positive
    return sentiment

# %% [markdown]
# Apply sentiment analysis

# %%
sentiment_list = [];
for headline in headlines_list:
    sentiment = get_sentiment(headline)
    sentiment_list.append(sentiment);
    print(f"Headline: {headline}\nSentiment: {sentiment}\n")
# Out:
# Headline: Russia raises forecast for 2024 oil, gas export revenues by $17.4 billion
# Sentiment: 1
#
# Headline: US Gulf Coast-bound fuel oil cargoes hit 5-yr low as refinery demand weakens
# Sentiment: 2
#
# Headline: How steelworkers are gambling on politics to block — or improve — the Nippon-US Steel deal
# Sentiment: 0
#
# Headline: S&P 500 Heads Toward Worst Week Since March 2023: Markets Wrap
# Sentiment: 0
#
# Headline: Nvidia stock tanks 5% amid rough week for chip stocks
# Sentiment: 0
#
# Headline: Florida Boomtown Borrows $65 Million to Help Fix Bursting Jail
# Sentiment: 0
#
# Headline: Why Gitlab Stock Rallied This Week
# Sentiment: 0
#
# Headline: Analysts adjust Bookings.com stock price target on travel market
# Sentiment: 0
#
# Headline: Stocks Tumble On Jobs Data, Nasdaq 100 Eyes Worst Week In 2 Years As Semiconductors Slump: What's Driving Markets Friday?
# Sentiment: 2
#
# Headline: 1 Wall Street Team Thinks Super Micro Computer Stock Is Going to $438. Is It Time to Sell?
# Sentiment: 0
#
# Headline: Why Nvidia Stock Is Plummeting Again Today
# Sentiment: 2
#
# Headline: Buy British stocks, says Goldman Sachs
# Sentiment: 0
#
# Headline: Spectrum Brands (NYSE:SPB) Q2 Earnings: Leading The Household Products Pack
# Sentiment: 1
#
# Headline: Q2 Earnings Highlights: Snap-on (NYSE:SNA) Vs The Rest Of The Professional Tools and Equipment Stocks
# Sentiment: 0
#
# Headline: Firing on All Cylinders: Sprouts (NASDAQ:SFM) Q2 Earnings Lead the Way
# Sentiment: 1
#
# Headline: Q2 Earnings Highs And Lows: O'Reilly (NASDAQ:ORLY) Vs The Rest Of The Auto Parts Retailer Stocks
# Sentiment: 0
#
# Headline: Q2 Automotive and Marine Retail Earnings: MarineMax (NYSE:HZO) Impresses
# Sentiment: 2
#
# Headline: Q2 Ground Transportation Earnings Review: First Prize Goes to Heartland Express (NASDAQ:HTLD)
# Sentiment: 0
#
# Headline: Utilities are almost as big an AI play as tech: Strategist
# Sentiment: 0
#
# Headline: Vivek Ramaswamy talks Fed policy, crypto, US economy agendas
# Sentiment: 0
#
# Headline: How Dell is riding the AI wave: Insights from CEO Michael Dell
# Sentiment: 0
#
# Headline: America has forgotten how to build homes: Redfin CEO
# Sentiment: 0
#
# Headline: Expect China to 'fight hard' against chip export controls
# Sentiment: 1
#
# Headline: How steelworkers are gambling on politics to block — or improve — the Nippon-US Steel deal
# Sentiment: 0
#
# Headline: Nvidia stock tanks 5% amid rough week for chip stocks
# Sentiment: 0
#
# Headline: Stock market today: Stocks erase gains, head for big weekly losses after jobs report
# Sentiment: 0
#
# Headline: 'The time has come': Why the August jobs report keeps the Fed on track for a 25 basis point rate cut
# Sentiment: 0
#
# Headline: One of the biggest AI stocks of the year hit with downgrade from JPMorgan
# Sentiment: 2
#
# Headline: August jobs report: Unemployment rate falls to 4.2%, labor market adds 142,000 jobs
# Sentiment: 0
#
# Headline: ​​Crypto won’t dethrone the dollar: CEO of America’s oldest bank
# Sentiment: 0
#
# Headline: The US economy may be on 'thinner' ice than investors think
# Sentiment: 2
#
# Headline: Fed Likely Ready to Start Cutting Rates, Governor Waller, NY Fed President Williams Say
# Sentiment: 0
#
# Headline: Apple's iPhone 16 Launch to Trigger 'Biggest Upgrade Cycle' Yet, Wedbush Reiterates
# Sentiment: 1
#
# Headline: ABM Industries Lifts Full-Year Earnings Outlook as Fiscal Third-Quarter Results Beat Estimates
# Sentiment: 1
#
# Headline: August Nonfarm Payrolls Miss Estimates, Unemployment Rate Edges Down
# Sentiment: 2
#
# Headline: BRP Slashes Full-Year Outlook as Lower Demand Impacts Fiscal Second-Quarter Results
# Sentiment: 2
#
# Headline: DocuSign Lifts Full-Year Revenue Guidance Following Fiscal Second-Quarter Beat
# Sentiment: 1
#
# Headline: Stock Futures Fall Ahead of August Jobs Report; Asia, Europe Down
# Sentiment: 2
#
# Headline: Nvidia’s AI chips are cheaper to rent in China than US
# Sentiment: 0
#
# Headline: New Zealand Housing Construction Slump Highlights Recession Risk
# Sentiment: 2
#
# Headline: Mortgage rates falling to 5% would get this party started
# Sentiment: 0
#
# Headline: Zoning reforms won’t save us, housing experts warn in Fannie survey
# Sentiment: 0
#
# Headline: Mortgage rates remain steady as Fed rate cut looms
# Sentiment: 1
#
# Headline: Average long-term US mortgage rates holds at 6.35% this week ahead of expected Fed rate cut
# Sentiment: 1
#
# Headline: Mortgage Rates in the US Hold at the Lowest Level Since May 2023
# Sentiment: 2
#
# Headline: These counties have the greatest risk of a housing downturn
# Sentiment: 2
#
# Headline: California settles lawsuit with Sacramento suburb over affordable housing project
# Sentiment: 0
#
# Headline: 7 ways to build credit — without a credit card
# Sentiment: 0
#
# Headline: How does inflation affect mortgage rates?
# Sentiment: 0
#
# Headline: Mortgage and refinance rates today, September 6, 2024: Rates drop 77 basis points in a year
# Sentiment: 0
#
# Headline: Russia raises forecast for 2024 oil, gas export revenues by $17.4 billion
# Sentiment: 1
#
# Headline: US Gulf Coast-bound fuel oil cargoes hit 5-yr low as refinery demand weakens
# Sentiment: 2
#
# Headline: S&P 500 Heads Toward Worst Week Since March 2023: Markets Wrap
# Sentiment: 0
#
# Headline: Nvidia’s $400 Billion Tumble This Week Makes Bitcoin Look Calm
# Sentiment: 0
#
# Headline: Coinbase Upgraded As Both Presidential Candidates Show Crypto Support; Analyst Sees Resilience Amid Regulatory Changes
# Sentiment: 1
#
# Headline: MicroStrategy Poised for Growth With Strong Bitcoin Exposure and Software Expansion: Analyst
# Sentiment: 1
#
# Headline: Illinois trucking company with 480 drivers abruptly ceases operations
# Sentiment: 2
#
# Headline: If I Buy A $100,000 Annuity, How Much Cash Will It Pay Me Each Month?
# Sentiment: 0
#
# Headline: Nvidia Stock Is Too Expensive, ‘Dean of Valuation’ Says. Here’s Where It Should Be Trading.
# Sentiment: 0
#
# Headline: Trump just called for a U.S. sovereign wealth fund. What would that look like?
# Sentiment: 0
#
# Headline: 13 states that don’t tax your retirement income
# Sentiment: 0
#
# Headline: Analyst Report: Kimco Realty Corp.
# Sentiment: 0
#
# Headline: Trump Media’s 69% Plunge Wipes Out Billions Before Lockups End
# Sentiment: 2
#
# Headline: Warren Buffett Recently Bought 8 Stocks. Here's the Best of the Bunch for Income Investors.
# Sentiment: 1
#
# Headline: Missouri Couple Holds Onto Family Car While Drowning In $240K Debt – Dave Ramsey's Brutal Response: 'You People Are Broke!'
# Sentiment: 0
#
# Headline: GameStop Stock Jumps After Roaring Kitty Tweet
# Sentiment: 1

# %% [markdown]
# Converting to categorical labels

# %%
sentiment_label = []
for i in range(len(sentiment_list)):
  if sentiment_list[i] == 0:
    sentiment_label.append('neutral')
  elif sentiment_list[i] == 1:
    sentiment_label.append('positive')
  elif sentiment_list[i] == 2:
    sentiment_label.append('negative')
    sentiment_list[i] = -1

# %% [markdown]
# #Visualisation

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Count the occurrences of each sentiment label
sentiment_counts = Counter(sentiment_label)

# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(sentiment_counts.keys(), sentiment_counts.values())
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment Distribution in Headlines')
plt.show()

# %%
import seaborn as sns

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(sentiment_counts.values(), labels=sentiment_counts.keys(), autopct='%1.1f%%', startangle=90)
plt.title('Sentiment Distribution in Headlines (Pie Chart)')
plt.show()

# %%
import pandas as pd

category_sentiment = pd.crosstab(sentiment_label, sentiment_list)
sns.heatmap(category_sentiment, annot=True, cmap='Blues')
plt.title('Sentiment Co-occurrence with Category')
plt.show()

# %%
pip install pywaffle
# Out:
# Collecting pywaffle
#   Downloading pywaffle-1.1.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting fontawesomefree (from pywaffle)
#   Downloading fontawesomefree-6.6.0-py3-none-any.whl.metadata (853 bytes)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pywaffle) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywaffle) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywaffle) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywaffle) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywaffle) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywaffle) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywaffle) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywaffle) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywaffle) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pywaffle) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->pywaffle) (1.16.0)
# Downloading pywaffle-1.1.1-py2.py3-none-any.whl (30 kB)
# Downloading fontawesomefree-6.6.0-py3-none-any.whl (25.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 51.7 MB/s eta 0:00:00
# Installing collected packages: fontawesomefree, pywaffle
# Successfully installed fontawesomefree-6.6.0 pywaffle-1.1.1

# %%
from pywaffle import Waffle

# Waffle chart
data = Counter(sentiment_label)
fig = plt.figure(
    FigureClass=Waffle,
    rows=5,
    values=data,
    colors=["green", "red", "gray"],
    title={'label': 'Sentiment Distribution', 'loc': 'center'},
)
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
import numpy as np

# Example: random size for bubbles
sizes = np.random.rand(len(sentiment_label)) * 1000  # Replace with actual size data

# Bubble plot
plt.scatter(sentiment_list, range(len(sentiment_list)), s=sizes, alpha=0.5, color='blue')
plt.xlabel('Sentiment (-1: Negative, 0: Neutral, 1: Positive)')
plt.ylabel('Index')
plt.title('Bubble Plot of Sentiment')
plt.show()
